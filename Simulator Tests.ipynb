# %%
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook

import numpy as np
import pandas as pd

# %%
test_v1 = pd.read_csv('Simulator/test_v1.csv')
print(test_v1)
# Out:
#          seed  level  vitamins_used  finished  num_ver_clears  num_hor_clears  \
# 0           2      0             13         1              17               0
# 1           2      1             21         1              40               0
# 2           2      2             31         1              59               0
# 3           2      3             26         1              60               0
# 4           2      4             59         1             113               9
# ...       ...    ...            ...       ...             ...             ...
# 1376167  ffff     16            111         1             258              17
# 1376168  ffff     17            176         1             384              12
# 1376169  ffff     18            174         1             390              21
# 1376170  ffff     19              9         0               8               0
# 1376171  ffff     20              9         0               8               0
#
#          num_vita_placed_top_row
# ...

# %%
finished_counts = test_v1['finished'].value_counts()
print(finished_counts)
vitamins_used = test_v1['vitamins_used'].mean()
print(vitamins_used)
# Out:
# 1    1027284
# 0     348888
# Name: finished, dtype: int64
# 89.47337251448221

# %%
finished_counts.plot(kind='pie')

# %%
test_v1_csv = pd.read_csv('Simulator/test_v1.csv')
finished_counts_v1 = test_v1_csv['finished'].value_counts()
print(finished_counts_v1)
finished_counts_v1.plot(kind='pie')

vitamins_used_v1 = test_v1_csv['vitamins_used'].mean()
print(vitamins_used_v1)
# Out:
# 1    1027284
# 0     348888
# Name: finished, dtype: int64
# 89.47337251448221

# %%
test_v2_csv = pd.read_csv('Simulator/test_v2.csv')
finished_counts_v2 = test_v2_csv['finished'].value_counts()
print(finished_counts_v2)
finished_counts_v2.plot(kind='pie')

vitamins_used_v2 = test_v2_csv['vitamins_used'].mean()
print(vitamins_used_v2)
# Out:
# 1    1240442
# 0     135730
# Name: finished, dtype: int64
# 106.62934429707914

# %%
test_v3_csv = pd.read_csv('Simulator/test_v3.csv')
finished_counts_v3 = test_v3_csv['finished'].value_counts()
print(finished_counts_v3)
finished_counts_v3.plot(kind='pie')
vitamins_used_v3 = test_v3_csv['vitamins_used'].mean()
print(vitamins_used_v3)
# Out:
# 1    1172190
# 0     203982
# Name: finished, dtype: int64
# 113.83185386710382

# %%
test_v4_csv = pd.read_csv('Simulator/test_v4.csv')
finished_counts_v4 = test_v4_csv['finished'].value_counts()
print(finished_counts_v4)
finished_counts_v4.plot(kind='pie')
vitamins_used_v4 = test_v4_csv['vitamins_used'].mean()
print(vitamins_used_v4)
# Out:
# 1    1206900
# 0     169272
# Name: finished, dtype: int64
# 364.8439410190005

# %%
test_e1_csv = pd.read_csv('Simulator/eval_1.csv')
finished_counts_e1 = test_e1_csv['finished'].value_counts()
print(finished_counts_e1)
finished_counts_e1.plot(kind='pie')
vitamins_used_e1 = test_e1_csv['vitamins_used'].mean()
print(vitamins_used_e1)
# Out:
# 0    5208
# 1     126
# Name: finished, dtype: int64
# 99.64304461942257

# %%
test_tvo_v1 = pd.read_csv('Simulator/test_tvo_v1.csv')
finished_counts_tvo_v1 = test_tvo_v1['finished'].value_counts()
print(finished_counts_tvo_v1)
finished_counts_tvo_v1.plot(kind='pie')
vitamins_used_tvo_v1 = test_tvo_v1['vitamins_used'].mean()
print("Vitamins used: ",vitamins_used_tvo_v1)
# Out:
# 1    1258244
# 0     117928
# Name: finished, dtype: int64
# Vitamins used:  135.62312123775226

# %%
test_tvo_v2 = pd.read_csv('Simulator/test_tvo_v2.csv')
finished_counts_tvo_v2 = test_tvo_v2['finished'].value_counts()
print(finished_counts_tvo_v2)
finished_counts_tvo_v2.plot(kind='pie')
vitamins_used_tvo_v2 = test_tvo_v2['vitamins_used'].mean()
print("Vitamins used: ",vitamins_used_tvo_v2)
# Out:
# 1    999106
# 0    377066
# Name: finished, dtype: int64
# Vitamins used:  162.19353540109813

# %%
test_tvo_v3 = pd.read_csv('Simulator/test_tvo_v3.csv')
finished_counts_tvo_v3 = test_tvo_v3['finished'].value_counts()
print(finished_counts_tvo_v3)
finished_counts_tvo_v3.plot(kind='pie')
vitamins_used_tvo_v3 = test_tvo_v3['vitamins_used'].mean()
print("Vitamins used: ",vitamins_used_tvo_v3)
# Out:
# 1    1115954
# 0     260218
# Name: finished, dtype: int64
# Vitamins used:  93.15443273079237

# %%
test_tvo_v4 = pd.read_csv('Simulator/test_tvo_v4.csv')
finished_counts_tvo_v4 = test_tvo_v4['finished'].value_counts()
print(finished_counts_tvo_v4)
finished_counts_tvo_v4.plot(kind='pie')
vitamins_used_tvo_v4 = test_tvo_v4['vitamins_used'].mean()
print("Vitamins used: ",vitamins_used_tvo_v4)
# Out:
# 0    854120
# 1    522052
# Name: finished, dtype: int64
# Vitamins used:  128.15461148751754

# %%
test_tvo_v5 = pd.read_csv('Simulator/test_tvo_v5.csv')
finished_counts_tvo_v5 = test_tvo_v5['finished'].value_counts()
print(finished_counts_tvo_v5)
finished_counts_tvo_v5.plot(kind='pie')
vitamins_used_tvo_v5 = test_tvo_v5['vitamins_used'].mean()
print("Vitamins used: ",vitamins_used_tvo_v5)
# Out:
# 1    1226808
# 0     149364
# Name: finished, dtype: int64
# Vitamins used:  202.98458477574025

# %%
df = pd.DataFrame({'ver':['V1', 'V2', 'V4', 'E1'], 'val':[vitamins_used, vitamins_used_v2, vitamins_used_v4,vitamins_used_e1]})
ax = df.plot.bar(x='ver', y='val', rot=0)

# %%
df = pd.DataFrame({'ver':['V1', 'V2', 'V3', 'V4','V5','V1_BST'], 'val':[vitamins_used_tvo_v1, vitamins_used_tvo_v2, vitamins_used_tvo_v3,vitamins_used_tvo_v4,vitamins_used_tvo_v5,vitamins_used_v1]})
ax = df.plot.bar(x='ver', y='val', rot=0)

# %%
df = pd.DataFrame({'ver':['V1', 'V2', 'V3', 'V4','V5', 'V1_BST'], 'val':[finished_counts_tvo_v1[1], finished_counts_tvo_v2[1], finished_counts_tvo_v3[1],finished_counts_tvo_v4[1],finished_counts_tvo_v5[1],finished_counts[1]]})
ax = df.plot.bar(x='ver', y='val', rot=0)
